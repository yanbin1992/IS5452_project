# %% [markdown]
# # additional dataset:
#
# https://www.kaggle.com/abhi8923shriv/sentiment-analysis-dataset?select=train.csv

# %%
import pandas as pd

# %%
ex_df = pd.read_csv('/content/extra_train.csv', encoding= 'unicode_escape')
ex_df.head()
# Out:
#        textID  ... Density (P/Km²)
# 0  cb774db0d1  ...              60
# 1  549e992a42  ...             105
# 2  088c60f138  ...              18
# 3  9642c003ef  ...             164
# 4  358bd9e861  ...              26
#
# [5 rows x 10 columns]

# %%
ex_df = ex_df[['text','sentiment']]
ex_df = ex_df[ex_df['sentiment'] == 'neutral']
ex_df = ex_df.replace('neutral', 2).reset_index(drop=True)

ex_df.head()
ex_df.to_csv('neutral.csv', index=None)

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
